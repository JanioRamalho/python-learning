# %% [markdown]
# # Exercícios
#
# ## 1. Faturamento do Melhor e do Pior Mês do Ano
#
# Qual foi o valor de vendas do melhor mês do Ano?
# E valor do pior mês do ano?

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = [25000, 29000, 22200, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 49051, 9650]

# %%
### Vamos começar analisando o que foi pedido de forma bem direta
'''
1. Maior valor de vendas
2. Pior valor de vendas
'''
# Poderiamos fazer apenas observando as listas e dizer qual a resposta que a questão pede.
# Porém, se fosse uma lista de milhares de elementos?? Seria impossível analisar no olho


meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = ([25000, 29000, 22200, 17750, 15870, 19900])
vendas_2sem = ([19850, 20120, 17540, 15555, 49051, 9650])
vendas_1sem.extend(vendas_2sem)
print(vendas_1sem)

print(f'Maior Venda: R$ {max(vendas_1sem):.2f}')
print(f'Menor Venda: R$ {min(vendas_1sem):.2f}')
# Out:
# [25000, 29000, 22200, 17750, 15870, 19900, 19850, 20120, 17540, 15555, 49051, 9650]
# Maior Venda: R$ 49051.00
# Menor Venda: R$ 9650.00

# %% [markdown]
# ## 2. Continuação
#
# Agora relacione as duas listas para printar 'O melhor mês do ano foi {} com {} vendas' e o mesmo para o pior mês do ano.
#
# Calcule também o faturamento total do Ano e quanto que o melhor mês representou do faturamento total.
#
# Obs: Para o faturamento total, pode usar a função sum(lista) que soma todos os itens de uma lista

# %%
for mes , venda in zip(meses , vendas_1sem):
# Out:
# O melhor mês do Ano foi set com 25000
# O melhor mês do Ano foi set com 29000
# O melhor mês do Ano foi set com 22200
# O melhor mês do Ano foi set com 17750
# O melhor mês do Ano foi set com 15870
# O melhor mês do Ano foi set com 19900
# O melhor mês do Ano foi set com 19850
# O melhor mês do Ano foi set com 20120
# O melhor mês do Ano foi set com 17540
# O melhor mês do Ano foi set com 15555
# O melhor mês do Ano foi set com 49051
# O melhor mês do Ano foi set com 9650

# %% [markdown]
# ## 3. Crie uma lista com o top 3 valores de vendas do ano (sem fazer "no olho")
#
# Dica: o método remove retira um item da lista.

# %%
top3 = []
