# %% [markdown]
# # Argumentos/Parâmetros da Função
#
# ### Estrutura:

# %% [raw]
# def minha_funcao(parametro1, parametro2, parametro3):
#     return parametro1 + parametro2 + parametro3

# %% [markdown]
# - Exemplo: nosso famoso print

# %%
vendas = 50
print('Produto', 'Iphone', 'Vendas', vendas)
# Out:
# Produto Iphone Vendas 50

# %% [markdown]
# - Só para mostrar o funcionamento, vamos criar uma função de soma

# %%
def minha_soma(num1, num2, num3):
    return num1 + num2 + num3


soma = minha_soma(10, 20, 0)
print(soma)
# Out:
# 30

# %% [markdown]
# - Vamos criar uma function com parâmetro
#
# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora de bebidas.
#
# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.
#
# Ex:<br>
# Vinho -> BEB12302<br>
# Cerveja -> BEB12043<br>
# Vodka -> BEB34501<br>
#
# Guaraná -> BSA11104<br>
# Coca -> BSA54301<br>
# Sprite -> BSA34012<br>
# Água -> BSA09871<br>
#
# Repare que bebidas não alcóolicas começam com BSA e bebidas alcoolicas começam com BEB.
#
# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de bebidas alcóolicas.

# %%
def eh_alcoolica(produto): #bebida é parâmetro 
    produto = produto.upper()
    if "BEB" in produto:
        return True
    else:
        return False
    

produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

for bebida in produtos:
    if eh_alcoolica(bebida): #produto é argumento
        print(f'Enviar {bebida.upper()} para o setor de bebudas alcóolicas')
# Out:
# Enviar BEB46275 para o setor de bebudas alcóolicas
# Enviar BEB21365 para o setor de bebudas alcóolicas
# Enviar BEB31623 para o setor de bebudas alcóolicas
# Enviar BEB73344 para o setor de bebudas alcóolicas
# Enviar BEB80694 para o setor de bebudas alcóolicas
# Enviar BEB19495 para o setor de bebudas alcóolicas
# Enviar BEB97471 para o setor de bebudas alcóolicas
# Enviar BEB62362 para o setor de bebudas alcóolicas
# Enviar BEB85146 para o setor de bebudas alcóolicas
# Enviar BEB48898 para o setor de bebudas alcóolicas
# Enviar BEB79496 para o setor de bebudas alcóolicas
# Enviar BEB15385 para o setor de bebudas alcóolicas
# Enviar BEB24213 para o setor de bebudas alcóolicas
# Enviar BEB56262 para o setor de bebudas alcóolicas
# Enviar BEB75073 para o setor de bebudas alcóolicas

# %% [markdown]
# ### Vamos criar uma função que tenha mais de um parâmetro

# %% [markdown]
# Ao invés de verificar se a bebida é somente alcoolica, vamos agora categorizar as bebidas a partir do código dela
# `BEB: Bebida alcóolica`
# `BSA: Bebida nao alcóolica`

# %%
def eh_da_categoria(bebida , cod_categoria):
    bebida = bebida.upper()
    if cod_categoria in bebida:
        return True
    else:
        False

produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

for produto in produtos:
    produto = produto.upper()
    if eh_da_categoria(produto, "BEB"):
        print(f'Enivar {produto} para o setor de bebidas alcóolicas')
    elif eh_da_categoria(produto, "BSA"):
        print(f'Enivar {produto} para o setor de bebidas não alcóolicas')
    else:
        print
# Out:
# Enivar BEB46275 para o setor de bebidas alcóolicas
# Enivar BSA45510 para o setor de bebidas não alcóolicas
# Enivar BEB21365 para o setor de bebidas alcóolicas
# Enivar BEB31623 para o setor de bebidas alcóolicas
# Enivar BSA62419 para o setor de bebidas não alcóolicas
# Enivar BEB73344 para o setor de bebidas alcóolicas
# Enivar BEB80694 para o setor de bebidas alcóolicas
# Enivar BSA11769 para o setor de bebidas não alcóolicas
# Enivar BEB19495 para o setor de bebidas alcóolicas
# Enivar BSA33484 para o setor de bebidas não alcóolicas
# Enivar BEB97471 para o setor de bebidas alcóolicas
# Enivar BEB62362 para o setor de bebidas alcóolicas
# Enivar BEB85146 para o setor de bebidas alcóolicas
# Enivar BEB48898 para o setor de bebidas alcóolicas
# Enivar BEB79496 para o setor de bebidas alcóolicas
# Enivar BSA59251 para o setor de bebidas não alcóolicas
# Enivar BEB15385 para o setor de bebidas alcóolicas
# Enivar BEB24213 para o setor de bebidas alcóolicas
# Enivar BEB56262 para o setor de bebidas alcóolicas
# Enivar BSA96915 para o setor de bebidas não alcóolicas
# Enivar BEB75073 para o setor de bebidas alcóolicas
